# %%
a = "hello , kaisa , hai hsdasdjkadka hj jj sd dw wd kwa asjdjka jsadjs ss dd ff ha"
k = int(input("enter a no : "))
d = ''
c =[]
e =''
for i in a:

    if i !=',' and i!=" ":
        d = d+i

    else:
        e=d
        d=''
        c.append(e)

for i in c:
    if len(i)>=k:
        print(i,end=' ')
# Out:
# enter a no : 5
# hello kaisa hsdasdjkadka asjdjka jsadjs
