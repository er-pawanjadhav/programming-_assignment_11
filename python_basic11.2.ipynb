# %%
a = "hello pawan jadhav this side "
k = int(input("enter a no : "))
d = ''

for i in range(len(a)):

    if i !=k:
        d = d+a[i]
print(d)
# Out:
# enter a no : 3
# helo pawan jadhav this side
