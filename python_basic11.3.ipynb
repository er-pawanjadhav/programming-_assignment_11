# %%
#3.	Write a Python program to split and join a string?

s = "hello guys how are you"
split_s =s.split(' ') 
print(split_s)
join_s = ' '.join(split_s)
print(join_s)
# Out:
# ['hello', 'guys', 'how', 'are', 'you']
# hello guys how are you
