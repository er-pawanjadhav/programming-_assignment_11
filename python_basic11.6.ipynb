# %%
a = 'hello how are you bro'
c = 'hey pawan jadhav this side'
d = []
e = []
for i in a:
    if i!=' ':
        d.append(i)
for i in c:
    if i!=' ':
        e.append(i)
e = set(e) 
d = set(d) 
e = e.intersection(d)
e = list(e)
print("common word from two strings are : ",e)
# Out:
# common word from two strings are :  ['e', 'h', 'y', 'w', 'a']
