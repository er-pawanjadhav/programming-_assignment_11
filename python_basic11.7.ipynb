# %%
a = "~!@#$%^&*()_{}|:+'<>?`[];'\',./"+'"'
a = list(a)
s = "hello guys how are you "
c = 0
for i in s:
    if i in a:
        c=c+1
if c>0:
    print("their is special character inside the string")
else:
    print("their is no special character inside the string")
# Out:
# their is no special character inside the string
